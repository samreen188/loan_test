# %%
import pandas as pd
df=pd.read_csv("loan.csv")
df
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %% [markdown]
# *** EXPLORATION

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
df.tail()
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area
# 362              177700     11300000  360.0             1.0      Urban
# 363               70900     11500000  360.0             1.0      Urban
# 364              199300     12600000  360.0             NaN  Semiurban
# 365              239300     15800000  360.0             1.0      Rural
# 366                   0      9800000  180.0             1.0      Rural

# %%
df.sample(4)
# Out:
#     Gender Married Dependents Education Self_Employed  Applicant_Income  \
# 196   Male     Yes          1  Graduate            No            479600
# 148   Male     Yes          1  Graduate            No            474200
# 0     Male     Yes          0  Graduate            No            572000
# 232   Male     Yes          0  Graduate            No            117300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area
# 196                   0     11400000  360.0             0.0  Semiurban
# 148               71700     13900000  360.0             1.0  Semiurban
# 0                     0     11000000  360.0             1.0      Urban
# 232              159400      2800000  180.0             1.0      Rural

# %%
df.shape
# Out:
# (367, 11)

# %%
df.size
# Out:
# 4037

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Applicant_Income', 'Coapplicant_Income', 'Loan_Amount', 'Term',
#        'Credit_History', 'Area'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Gender                 object
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income      int64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=367, step=1)

# %%
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              356 non-null    object
#  1   Married             367 non-null    object
#  2   Dependents          357 non-null    object
#  3   Education           367 non-null    object
#  4   Self_Employed       344 non-null    object
#  5   Applicant_Income    367 non-null    int64
#  6   Coapplicant_Income  367 non-null    int64
#  7   Loan_Amount         367 non-null    int64
#  8   Term                361 non-null    float64
#  9   Credit_History      338 non-null    float64
#  10  Area                367 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 31.7+ KB

# %%
df.describe()
# Out:
#        Applicant_Income  Coapplicant_Income   Loan_Amount        Term  \
# count      3.670000e+02        3.670000e+02  3.670000e+02  361.000000
# mean       4.805599e+05        1.569578e+05  1.342779e+07  342.537396
# std        4.910685e+05        2.334232e+05  6.296143e+06   65.156643
# min        0.000000e+00        0.000000e+00  0.000000e+00    6.000000
# 25%        2.864000e+05        0.000000e+00  1.000000e+07  360.000000
# 50%        3.786000e+05        1.025000e+05  1.250000e+07  360.000000
# 75%        5.060000e+05        2.430500e+05  1.575000e+07  360.000000
# max        7.252900e+06        2.400000e+06  5.500000e+07  480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.describe(include="all")
# Out:
#        Gender Married Dependents Education Self_Employed  Applicant_Income  \
# count     356     367        357       367           344      3.670000e+02
# unique      2       2          4         2             2               NaN
# top      Male     Yes          0  Graduate            No               NaN
# freq      286     233        200       283           307               NaN
# mean      NaN     NaN        NaN       NaN           NaN      4.805599e+05
# std       NaN     NaN        NaN       NaN           NaN      4.910685e+05
# min       NaN     NaN        NaN       NaN           NaN      0.000000e+00
# 25%       NaN     NaN        NaN       NaN           NaN      2.864000e+05
# 50%       NaN     NaN        NaN       NaN           NaN      3.786000e+05
# 75%       NaN     NaN        NaN       NaN           NaN      5.060000e+05
# max       NaN     NaN        NaN       NaN           NaN      7.252900e+06
#
# ...

# %%
df.isnull()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0     False    False       False      False          False             False
# 1     False    False       False      False          False             False
# 2     False    False       False      False          False             False
# 3     False    False       False      False          False             False
# 4     False    False       False      False          False             False
# ..      ...      ...         ...        ...            ...               ...
# 362   False    False       False      False          False             False
# 363   False    False       False      False          False             False
# 364   False    False       False      False          False             False
# 365   False    False       False      False          False             False
# 366   False    False       False      False          False             False
#
# ...

# %%
df.isnull().sum()
# Out:
# Gender                11
# Married                0
# Dependents            10
# Education              0
# Self_Employed         23
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                   6
# Credit_History        29
# Area                   0
# dtype: int64

# %% [markdown]
# *** CLEANING

# %%
df.rename(columns={"Usage (Area)":"area" },inplace=True)
df
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df.dropna()
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 4     Male      No          0  Not Graduate            No            327600
# 5     Male     Yes          0  Not Graduate           Yes            216500
# ..     ...     ...        ...           ...           ...               ...
# 361   Male     Yes          1      Graduate            No            226900
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df.fillna(2)
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df.drop(columns=["Education"])
# Out:
#     Gender Married Dependents Self_Employed  Applicant_Income  \
# 0     Male     Yes          0            No            572000
# 1     Male     Yes          1            No            307600
# 2     Male     Yes          2            No            500000
# 3     Male     Yes          2            No            234000
# 4     Male      No          0            No            327600
# ..     ...     ...        ...           ...               ...
# 362   Male     Yes         3+           Yes            400900
# 363   Male     Yes          0            No            415800
# 364   Male      No          0            No            325000
# 365   Male     Yes          0            No            500000
# 366   Male      No          0           Yes            920000
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area
# 0                     0     11000000  360.0             1.0      Urban
# 1                150000     12600000  360.0             1.0      Urban
# ...

# %% [markdown]
# *** MANIPULATION

# %%
df["Amount"]=df["Loan_Amount"].fillna(df["Loan_Amount"].mean())
df
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df[["Gender","Term","Area"]]
# Out:
#     Gender   Term       Area
# 0     Male  360.0      Urban
# 1     Male  360.0      Urban
# 2     Male  360.0      Urban
# 3     Male  360.0      Urban
# 4     Male  360.0      Urban
# ..     ...    ...        ...
# 362   Male  360.0      Urban
# 363   Male  360.0      Urban
# 364   Male  360.0  Semiurban
# 365   Male  360.0      Rural
# 366   Male  180.0      Rural
#
# [367 rows x 3 columns]

# %%
df["Term"].mean()
# Out:
# 342.53739612188366

# %%
df["Term"].mode()
# Out:
# 0    360.0
# Name: Term, dtype: float64

# %%
df["Term"].median()
# Out:
# 360.0

# %%
df.empty
# Out:
# False

# %%
df.dtypes
# Out:
# Gender                 object
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income      int64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# Amount                  int64
# dtype: object

# %%
df["Term"].astype(bool)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 362    True
# 363    True
# 364    True
# 365    True
# 366    True
# Name: Term, Length: 367, dtype: bool

# %%
df.dtypes
# Out:
# Gender                 object
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income      int64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# Amount                  int64
# dtype: object

# %% [markdown]
# ***FILTERATION

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0     Male     Yes          0      Graduate            No            572000
# 1     Male     Yes          1      Graduate            No            307600
# 2     Male     Yes          2      Graduate            No            500000
# 3     Male     Yes          2      Graduate            No            234000
# 4     Male      No          0  Not Graduate            No            327600
# ..     ...     ...        ...           ...           ...               ...
# 362   Male     Yes         3+  Not Graduate           Yes            400900
# 363   Male     Yes          0      Graduate            No            415800
# 364   Male      No          0      Graduate            No            325000
# 365   Male     Yes          0      Graduate            No            500000
# 366   Male      No          0      Graduate           Yes            920000
#
# ...

# %%
df.filter(like="Term", axis=1)
# Out:
#       Term
# 0    360.0
# 1    360.0
# 2    360.0
# 3    360.0
# 4    360.0
# ..     ...
# 362  360.0
# 363  360.0
# 364  360.0
# 365  360.0
# 366  180.0
#
# [367 rows x 1 columns]

# %%
df.groupby("Term")["Amount"].sum()
# Out:
# Term
# 6.0         9500000
# 12.0       26000000
# 36.0       11800000
# 60.0       13900000
# 84.0       31900000
# 120.0       8000000
# 180.0     219600000
# 240.0      54700000
# 300.0      91800000
# 350.0      13300000
# 360.0    4294400000
# 480.0      74100000
# Name: Amount, dtype: int64

# %% [markdown]
# ***VISUALIZATION

# %%
df["Amount"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Amount'>

# %%
df["Term"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Term'>

# %%
df["Dependents"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Amount"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df["Amount"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Term"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Amount"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Amount'>

# %%
df["Dependents"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Dependents'>

# %% [markdown]
# ***FILE SAVE

# %%
df= pd.read_csv("loan.csv")
df
df.to_excel("loan_test.xlsx", sheet_name="loansheet")
